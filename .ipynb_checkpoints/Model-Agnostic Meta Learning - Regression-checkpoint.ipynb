# %% [markdown]
# # Model-Agnostic Meta Learning - Regression

# %% [markdown]
# This is an implementation of the paper "Model-Agnostic Meta Learning for Adaptation of Deep Networks"
# Paper link: https://arxiv.org/pdf/1703.03400.pdf

# %%
import math
import random
import copy
import torch
import matplotlib.pyplot as plt
from torch import nn
from torch.optim import Adam

# %%
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.sequential_net = nn.Sequential(
          nn.Linear(1, 32),
          nn.ReLU(),
          nn.Linear(32, 32),
          nn.ReLU(),
          nn.Linear(32, 1),
        )
        
    def forward(self, x):
        return self.sequential_net(x)

# %%
model = Model()
optimizer = Adam(list(model.parameters()), lr=1e-4)

# %%
for _ in range(0, 10000):
    inner_x = torch.rand(5, 1)*4*math.pi - 2*math.pi
    inner_true_y = torch.sin(inner_x)
    
    outer_x = torch.rand(5, 1)*4*math.pi - 2*math.pi
    outer_true_y = torch.sin(outer_x)
    
    new_parameters = list(model.parameters()).copy() 
    model.train()
    for _ in range(0, 5):
        inner_pred_y = model(inner_x)
        loss = nn.MSELoss()
        output = loss(inner_pred_y, inner_true_y)
        grads = torch.autograd.grad(output, list(model.parameters()),create_graph=True)
        new_parameters = [(new_parameters[i] - 1e-4 * grads[i]) for i in range(0, len(grads))]
        
        
    state_dict = model.state_dict()
    for n_p, i in zip(new_parameters, state_dict):
        state_dict[i] = n_p
    model.load_state_dict(state_dict)
    
    outer_pred_y = model(outer_x)
    loss_1 = nn.MSELoss()
    loss_1 = loss_1(outer_pred_y, outer_true_y)
    loss_1.backward()
    
    optimizer.step()
    optimizer.zero_grad()

# %%
test_x = torch.arange(-2*math.pi, 2*math.pi, step=0.01).unsqueeze(1)
test_y = torch.sin(test_x)

pred_y = model(test_x)

plt.plot(test_x.data.numpy(), test_y.data.numpy(), label='sin(x)')
plt.plot(test_x.data.numpy(), pred_y.data.numpy(), label='model(x)')
plt.legend()
plt.show()
